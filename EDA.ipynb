# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('/Users/suimeng/Desktop/CS668_Project/CS668-2021-MS/hotel_bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# hotel
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status
# reservation_status_date

# %%
for col in range(len(df.columns)): 
    print(df.columns[col])
    print(df.iloc[:,col].unique(), '\n')
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
#
# is_canceled
# [0 1]
#
# lead_time
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## Clean Data

# %%
# check the nan
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ### solution for Null value
# 1. country has 488 records with nan value, compared with the number of row we have, it is fine to delete the related rows
# 2. agent has 16340 records, which is 10% of all records, considering replace row by mean/mode/median
# 3. company has 112593 records. Based on common sence, company will not be the essential fact to effect cancellation. It is reasonanle to delete the columns

# %%
# drop null row 
# drop country, agent, children
df_Null = df.dropna(subset=['country','agent','children'], axis = 0)

# drop column company 
df_Null = df_Null.drop(['company'], axis = 1)

# save clean file 
cwd = os.getcwd()
#df_Null.to_csv(f'{cwd}/clean_data.csv')

# %% [markdown]
# ## Plotting

# %%
df_Null.arrival_date_month = (pd.to_datetime(df_Null.arrival_date_month, format='%B')).dt.month

# %%
df_Null.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year  \
# 3  Resort Hotel            0         13               2015
# 4  Resort Hotel            0         14               2015
# 5  Resort Hotel            0         14               2015
# 7  Resort Hotel            0          9               2015
# 8  Resort Hotel            1         85               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 3                   7                        27                          1
# 4                   7                        27                          1
# 5                   7                        27                          1
# 7                   7                        27                          1
# 8                   7                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 3                        0                     1       1  ...
# ...

# %%
# booking demond by week
# booking demond by monthes
# booking demond by years

booking_month = pd.pivot_table(df_Null, values = 'is_canceled', columns = ['hotel'], index=['arrival_date_month'], aggfunc='count')

fig, ax = plt.subplots(figsize = (15,4))
labels = booking_month.index
ax.bar(labels,booking_month['City Hotel'], label = 'City Hotel', width=0.5)
ax.bar(labels,booking_month['Resort Hotel'], label = 'Resort Hotel',width=0.5,color = 'g')
ax.set_ylabel('# of booking')
ax.set_xlabel('Month')
ax.set_title('Booking situation by Month')
ax.legend()
plt.show()

# %%
booking_week = pd.pivot_table(df_Null, values = 'is_canceled', columns = ['hotel'], index=['arrival_date_week_number'], aggfunc='count')

fig, ax = plt.subplots(figsize = (15,4))
labels = booking_week.index
ax.bar(labels,booking_week['City Hotel'], label = 'City Hotel', width=0.5)
ax.bar(labels,booking_week['Resort Hotel'], label = 'Resort Hotel',width=0.5,color = 'g')
ax.set_ylabel('# of booking')
ax.set_xlabel('Week')
ax.set_title('Booking situation by Week')
ax.legend()
plt.show()

# %%
booking_yr = pd.pivot_table(df_Null, values = 'is_canceled', columns = ['hotel'], index=['arrival_date_year'], aggfunc='count')

fig, ax = plt.subplots(figsize = (15,4))
labels = booking_yr.index
ax.bar(labels,booking_yr['City Hotel'], label = 'City Hotel', width=0.5)
ax.bar(labels,booking_yr['Resort Hotel'], label = 'Resort Hotel',width=0.5,color = 'g')
ax.set_ylabel('# of booking')
ax.set_xlabel('Year')
ax.set_title('Booking situation by Year')
ax.legend()
plt.show()

# %%
# booking demond by country 
# booking demond by room type 
# booking demond by customer_type 
# the same category for cancellation

# %%
booking_country = pd.pivot_table(df_Null, values = 'is_canceled', index=['country'], aggfunc='count')
booking_country['cty_percentage'] = round(booking_country['is_canceled']/len(df_Null),4)*100

# %%
booking_country.sort_values(by='cty_percentage', ascending=False)
# Out:
#          is_canceled  cty_percentage
# country
# PRT            37591           36.53
# GBR            10889           10.58
# FRA             9810            9.53
# ESP             7848            7.63
# DEU             6998            6.80
# ...              ...             ...
# KHM                2            0.00
# IMN                2            0.00
# HND                1            0.00
# GUY                1            0.00
# ZWE                4            0.00
#
# [174 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = booking_country.index
sizes = booking_country.cty_percentage

fig1, ax1 = plt.subplots(figsize = (10,10))
cmap = plt.get_cmap("tab20c")
colors = cmap(np.arange(20))

# only show the coutry whose percentage is higher 1%
def my_autopct(pct):
    return ('%.2f' % pct) if pct > 1 else ''

def get_new_labels(sizes, labels):
    new_labels = [label if size > 1 else '' for size, label in zip(sizes, labels)]
    return new_labels

ax1.pie(sizes, labels=get_new_labels(sizes, labels), autopct=my_autopct,
        shadow=False, startangle=90, colors = colors )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
